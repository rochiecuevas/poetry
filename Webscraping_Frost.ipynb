# %% [markdown]
# # Comparative analysis of Robert Frost's poems

# %% [markdown]
# ## Webscraping

# %%
# Dependencies

# to scrape the data from websites
from requests import get
from bs4 import BeautifulSoup

# to make the scraping more human-like by controlling the crawl rate
from IPython.core.display import clear_output
from time import sleep, time
from random import randint

# just in case of errors
from warnings import warn

# %%
# State the source of the data (there are four pages to scrape)
pages = [str(i) for i in range(1,5)]
url = "https://www.poetryfoundation.org/search?query=Robert%20Frost&refinement=poems&page="

# %%
# Create an empty list for parsed data from web scraping
# So there's no need to scrape repeatedly
soups = []
    
# Prepare the loop through the pages
start_time = time()
requests = 0

# Loop through the pages
for page in pages:
    # Make a get request for the contents of the URL
    response = get(url + page)
    
    # Pause the loop
    sleep(randint(8,15))
    
    # Monitor the requests
    requests += 1
    elapsed_time = time() - start_time
    print(f"Request {requests}; Frequency: {requests/elapsed_time} requests/sec")
    clear_output(wait = True) # to replace output with new one (instead of printing many outputs)
    
    # If there's an error, throw an error warning
    if response.status_code != 200:
        warn(f"Request: {requests}; Status code: {response.status_code}")
    
    # If there are more than 5 requests, break the loop
    if requests > 5:
        warn("Number of requests more than expected.")
        break
    
    # Scrape with BeautifulSoup
    page_soup = BeautifulSoup(response.text, "html.parser")
    soups.append(page_soup)
# Out:
# Request 4; Frequency: 0.0759237728617862 requests/sec

# %%
# Create empty lists for links and titles of poems authored by Robert Frost
# NB: There are poems in the list that refer to him but not authored by him
links = []
titles = []

for soup in soups:
    soup1 = soup.find_all("div", class_ = "c-feature")
    
    for item in soup1:
        if item.find("div", class_ = "c-feature-sub").text[4:-1] == "Robert Frost":
            soup2 = item.find("div", class_ = "c-feature-hd") 
            if soup2 is not None:
                titles.append(soup2.a.text)
                links.append(soup2.a["href"])
            else:
                continue # go to the next item
        else:
            continue # go to the next item

# %% [markdown]
# ## Load the poems into a dataframe

# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Load the titles and the links in a dataframe
poems = pd.DataFrame({"title": titles, 
                      "link": links})
print(f"Robert Frost has {len(poems)} poems that are currently shared by the Poetry Foundation.")
# Out:
# Robert Frost has 53 poems that are currently shared by the Poetry Foundation.

# %%
# Preview the poem title and their links in the dataframe
poems.head(6)
# Out:
#                        title  \
# 0                    October
# 1                ‘Out, Out—’
# 2  Acquainted with the Night
# 3        After Apple-Picking
# 4                    Birches
# 5            Christmas Trees
#
#                                                 link
# 0  https://www.poetryfoundation.org/poems/53084/o...
# 1  https://www.poetryfoundation.org/poems/53087/o...
# 2  https://www.poetryfoundation.org/poems/47548/a...
# 3  https://www.poetryfoundation.org/poems/44259/a...
# 4  https://www.poetryfoundation.org/poems/44260/b...
# 5  https://www.poetryfoundation.org/poems/57834/c...

# %% [markdown]
# ## Scrape each poem, clean the lines of each poem for special characters, and add the lines to the dataframe

# %%
# Create an empty list of lines of poetry
poem_lines = []

# Prepare for looping through the links
start_time = time()
requests = 0

# Loop through the links
for link in poems["link"]:
    
    # Make a get request for the contents of the link
    response2 = get(link)
    
    # Pause the loop
    sleep(randint(8,15))
    
    # Monitor the requests
    requests += 1
    elapsed_time = time() - start_time
    print(f"Request {requests}; Frequency: {requests/elapsed_time} requests/sec")
    clear_output(wait = True) # to replace output with new one (instead of printing many outputs)
    
    # If there's an error, throw an error warning
    if response.status_code != 200:
        warn(f"Request: {requests}; Status code: {response.status_code}")
    
    # If there are more than 53 requests (53 poems), break the loop
    if requests > len(poems):
        warn("Number of requests more than expected.")
        break
        
    # Scrape with BeautifulSoup
    poem_soup = BeautifulSoup(response2.text, "html.parser")
    
    # List the lines found in the URL
    lines_html = poem_soup.find("div", {"class": "o-poem"})
    
    if lines_html is not None:
        lines_html = list(lines_html)[1:-1]
    else: 
        lines_html = ""
    
    poem_lines.append(lines_html)
# Out:
# Request 53; Frequency: 0.0741448840588769 requests/sec

# %%
# Create a function that loops through a list of poems and extracts lines of text
def extract_text(poem_list):
    poem_lines2 = []
    for poem in poem_list:
        # Create an empty list
        lines = []
        
        # Loop through each poem (a list of lines), extract the text, add to the empty list
        for line in poem:
            lines.append(line.text)
        poem_lines2.append(lines)    
            
    return poem_lines2

# %%
# Use the extract_text function to get the text from relatively clean lists of lines
poem1 = extract_text(poem_lines[0:5])
poem3 = extract_text(poem_lines[6:54])

# Perform further cleaning of the list for the 6th poem
poem2 = []
for line in poem_lines[5][2:-1]:
    poem2.append(line.text)
    
# Concatenate the three poem lists to poem_lines2
# NB: Put the list of lines in a big list so that the big list is counted as an item in poem_lines3
poem_lines3 = []
poem_lines3 = poem1 + [poem2] + poem3

# Check the size of poem_lines3
len(poem_lines3)
# Out:
# 53

# %%
poem_lines3
# Out:
# [['O hushed October morning mild,',
#   'Thy leaves have ripened to the fall;',
#   'Tomorrow’s wind, if it be wild,',
#   'Should waste them all.',
#   'The crows above the forest call;',
#   'Tomorrow they may form and go.',
#   'O hushed October morning mild,',
#   'Begin the hours of this day slow.',
#   'Make the day seem to us less brief.',
#   'Hearts not averse to being beguiled,',
#   'Beguile us in the way you know.',
#   'Release one leaf at break of day;',
#   'At noon release another leaf;',
#   'One from our trees, one far away.',
#   'Retard the sun with gentle mist;',
#   'Enchant the land with amethyst.',
#   'Slow, slow!',
#   'For the grapes’ sake, if they were all,',
#   'Whose leaves already are burnt with frost,',
#   'Whose clustered fruit must else be lost—',
#   'For the grapes’ sake along the wall.',
#   '',
#   ''],
#  ['The buzz saw snarled and rattled in the yard',
#   'And made dust and dropped stove-length sticks of wood,',
#   'Sweet-scented stuff when the breeze drew across it.',
#   'And from there those that lifted eyes could count',
#   'Five mountain ranges one behind the other',
#   'Under the sunset far into Vermont.',
#   'And the saw snarled and rattled, snarled and rattled,',
#   'As it ran light, or had to bear a load.',
#   'And nothing happened: day was all but done.',
#   'Call it a day, I wish they might have said',
#   'To please the boy by giving him the half hour',
#   'That a boy counts so much when saved from work.',
#   'His sister stood beside him in her apron',
#   'To tell them ‘Supper.’ At the word, the saw,',
#   'As if to prove saws knew what supper meant,',
#   'Leaped out at the boy’s hand, or seemed to leap—',
#   'He must have given the hand. However it was, ',
#   'Neither refused the meeting. But the hand!',
#   'The boy’s first outcry was a rueful laugh,',
#   'As he swung toward them holding up the hand',
#   'Half in appeal, but half as if to keep',
#   'The life from spilling. Then the boy saw all—',
#   'Since he was old enough to know, big boy',
#   'Doing a man’s work, though a child at heart— ',
#   'He saw all spoiled. ‘Don’t let him cut my hand off—',
#   'The doctor, when he comes. Don’t let him, sister!’',
#   'So. But the hand was gone already.',
#   'The doctor put him in the dark of ether.',
#   'He lay and puffed his lips out with his breath.',
#   'And then—the watcher at his pulse took fright.',
#   'No one believed. They listened at his heart.',
#   'Little—less—nothing!—and that ended it. ',
#   'No more to build on there. And they, since they',
#   'Were not the one dead, turned to their affairs.',
#   ''],
#  ['I have been one acquainted with the night.',
#   '\r I have walked out in rain—and back in rain.',
#   '\r I have outwalked the furthest city light.',
#   '',
#   '\r I have looked down the saddest city lane.',
#   '\r I have passed by the watchman on his beat',
#   '\r And dropped my eyes, unwilling to explain.',
#   '',
#   '\r I have stood still and stopped the sound of feet',
#   '\r When far away an interrupted cry',
#   '\r Came over houses from another street,',
#   '',
#   '\r But not to call me back or say good-bye;',
#   '\r And further still at an unearthly height,',
#   '\r One luminary clock against the sky',
#   '',
#   '\r Proclaimed the time was neither wrong nor right.\xa0',
#   '\r I have been one acquainted with the night.',
#   ''],
#  ["My long two-pointed ladder's sticking through a tree ",
#   'Toward heaven still, ',
#   "And there's a barrel that I didn't fill ",
#   'Beside it, and there may be two or three ',
#   "Apples I didn't pick upon some bough. ",
#   'But I am done with apple-picking now. ',
#   'Essence of winter sleep is on the night, ',
#   'The scent of apples: I am drowsing off. ',
#   'I cannot rub the strangeness from my sight ',
#   'I got from looking through a pane of glass ',
#   'I skimmed this morning from the drinking trough ',
#   'And held against the world of hoary grass. ',
#   'It melted, and I let it fall and break. ',
#   'But I was well ',
#   'Upon my way to sleep before it fell, ',
#   'And I could tell ',
#   'What form my dreaming was about to take. ',
#   'Magnified apples appear and disappear, ',
#   'Stem end and blossom end, ',
#   'And every fleck of russet showing clear. ',
#   'My instep arch not only keeps the ache, ',
#   'It keeps the pressure of a ladder-round. ',
#   'I feel the ladder sway as the boughs bend. ',
#   'And I keep hearing from the cellar bin ',
#   'The rumbling sound ',
#   'Of load on load of apples coming in. ',
#   'For I have had too much ',
#   'Of apple-picking: I am overtired ',
#   'Of the great harvest I myself desired. ',
#   'There were ten thousand thousand fruit to touch, ',
#   'Cherish in hand, lift down, and not let fall. ',
#   'For all ',
#   'That struck the earth, ',
#   'No matter if not bruised or spiked with stubble, ',
#   'Went surely to the cider-apple heap ',
#   'As of no worth. ',
#   'One can see what will trouble ',
#   'This sleep of mine, whatever sleep it is. ',
#   'Were he not gone, ',
#   "The woodchuck could say whether it's like his ",
#   'Long sleep, as I describe its coming on, ',
#   'Or just some human sleep. ',
#   '',
#   ''],
#  ['When I see birches bend to left and right',
#   '\r Across the lines of straighter darker trees,',
#   "\r I like to think some boy's been swinging them.",
#   "\r But swinging doesn't bend them down to stay",
#   '\r As ice-storms do. Often you must have seen them',
#   '\r Loaded with ice a sunny winter morning',
#   '\r After a rain. They click upon themselves',
#   '\r As the breeze rises, and turn many-colored',
#   '\r As the stir cracks and crazes their enamel.',
#   "\r Soon the sun's warmth makes them shed crystal shells",
#   '\r Shattering and avalanching on the snow-crust—',
#   '\r Such heaps of broken glass to sweep away',
#   "\r You'd think the inner dome of heaven had fallen.",
#   '\r They are dragged to the withered bracken by the load,',
#   '\r And they seem not to break; though once they are bowed',
#   '\r So low for long, they never right themselves:',
#   '\r You may see their trunks arching in the woods',
#   '\r Years afterwards, trailing their leaves on the ground',
#   '\r Like girls on hands and knees that throw their hair',
#   '\r Before them over their heads to dry in the sun.',
#   '\r But I was going to say when Truth broke in',
#   '\r With all her matter-of-fact about the ice-storm',
#   '\r I should prefer to have some boy bend them',
#   '\r As he went out and in to fetch the cows—',
#   '\r Some boy too far from town to learn baseball,',
#   '\r Whose only play was what he found himself,',
#   '\r Summer or winter, and could play alone.',
#   "\r One by one he subdued his father's trees",
#   '\r By riding them down over and over again',
#   '\r Until he took the stiffness out of them,',
#   '\r And not one but hung limp, not one was left',
#   '\r For him to conquer. He learned all there was',
#   '\r To learn about not launching out too soon',
#   '\r And so not carrying the tree away',
#   '\r Clear to the ground. He always kept his poise',
#   '\r To the top branches, climbing carefully',
#   '\r With the same pains you use to fill a cup',
#   '\r Up to the brim, and even above the brim.',
#   '\r Then he flung outward, feet first, with a swish,',
#   '\r Kicking his way down through the air to the ground.',
#   '\r So was I once myself a swinger of birches.',
#   '\r And so I dream of going back to be.',
#   "\r It's when I'm weary of considerations,",
#   '\r And life is too much like a pathless wood',
#   '\r Where your face burns and tickles with the cobwebs',
#   '\r Broken across it, and one eye is weeping',
#   "\r From a twig's having lashed across it open.",
#   "\r I'd like to get away from earth awhile",
#   '\r And then come back to it and begin over.',
#   '\r May no fate willfully misunderstand me',
#   '\r And half grant what I wish and snatch me away',
#   "\r Not to return. Earth's the right place for love:",
#   "\r I don't know where it's likely to go better.",
#   "\r I'd like to go by climbing a birch tree,",
#   '\r And climb black branches up a snow-white trunk',
#   'Toward heaven, till the tree could bear no more,',
#   '\r But dipped its top and set me down again.',
#   '\r That would be good both going and coming back.',
#   '\r One could do worse than be a swinger of birches.',
#   ''],
#  ['The city had withdrawn into itself',
#   'And left at last the country to the country;',
#   'When between whirls of snow not come to lie',
#   'And whirls of foliage not yet laid, there drove',
#   'A stranger to our yard, who looked the city,',
#   'Yet did in country fashion in that there',
#   'He sat and waited till he drew us out',
#   'A-buttoning coats to ask him who he was.',
#   'He proved to be the city come again',
#   'To look for something it had left behind',
#   'And could not do without and keep its Christmas.',
#   'He asked if I would sell my Christmas trees;',
#   'My woods—the young fir balsams like a place',
#   'Where houses all are churches and have spires.',
#   'I hadn’t thought of them as Christmas Trees.',
#   'I doubt if I was tempted for a moment',
#   'To sell them off their feet to go in cars',
#   'And leave the slope behind the house all bare,',
#   'Where the sun shines now no warmer than the moon.',
#   'I’d hate to have them know it if I was.',
#   'Yet more I’d hate to hold my trees except',
#   'As others hold theirs or refuse for them,',
#   'Beyond the time of profitable growth,',
#   'The trial by market everything must come to.',
#   'I dallied so much with the thought of selling.',
#   'Then whether from mistaken courtesy',
#   'And fear of seeming short of speech, or whether',
#   'From hope of hearing good of what was mine, I said,',
#   '“There aren’t enough to be worth while.”',
#   '“I could soon tell how many they would cut,',
#   'You let me look them over.”',
#   '',
#   '\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0“You could look.',
#   'But don’t expect I’m going to let you have them.”',
#   'Pasture they spring in, some in clumps too close',
#   'That lop each other of boughs, but not a few',
#   'Quite solitary and having equal boughs',
#   'All round and round. The latter he nodded “Yes” to,',
#   'Or paused to say beneath some lovelier one,',
#   'With a buyer’s moderation, “That would do.”',
#   'I thought so too, but wasn’t there to say so.',
#   'We climbed the pasture on the south, crossed over,',
#   'And came down on the north. He said, “A thousand.”',
#   '',
#   '“A thousand Christmas trees!—at what apiece?”',
#   '',
#   'He felt some need of softening that to me:',
#   '“A thousand trees would come to thirty dollars.”',
#   '',
#   'Then I was certain I had never meant',
#   'To let him have them. Never show surprise!',
#   'But thirty dollars seemed so small beside',
#   'The extent of pasture I should strip, three cents',
#   '(For that was all they figured out apiece),',
#   'Three cents so small beside the dollar friends',
#   'I should be writing to within the hour',
#   'Would pay in cities for good trees like those,',
#   'Regular vestry-trees whole Sunday Schools',
#   'Could hang enough on to pick off enough.',
#   'A thousand Christmas trees I didn’t know I had!',
#   'Worth three cents more to give away than sell,',
#   'As may be shown by a simple calculation.',
#   'Too bad I couldn’t lay one in a letter.',
#   'I can’t help wishing I could send you one,'],
#  ['The way a crow',
#   '\r Shook down on me',
#   '\r The dust of snow',
#   '\r From a hemlock tree',
#   '',
#   '\r Has given my heart',
#   '\r A change of mood',
#   '\r And saved some part',
#   '\r Of a day I had rued.',
#   ''],
#  ['Some say the world will end in fire,',
#   '\r Some say in ice.',
#   '\r From what I’ve tasted of desire',
#   '\r I hold with those who favor fire.',
#   '\r But if it had to perish twice,',
#   '\r I think I know enough of hate',
#   '\r To say that for destruction ice',
#   '\r Is also great',
#   '\r And would suffice.',
#   ''],
#  ['Here come real stars to fill the upper skies,',
#   '\r And here on earth come emulating flies,',
#   '\r That though they never equal stars in size,',
#   '\r (And they were never really stars at heart)',
#   '\r Achieve at times a very star-like start.',
#   "\r Only, of course, they can't sustain the part.",
#   ''],
#  ['',
#   '\r Others taunt me with having knelt at well-curbs',
#   '\r Always wrong to the light, so never seeing',
#   '\r Deeper down in the well than where the water',
#   '\r Gives me back in a shining surface picture',
#   '\r Me myself in the summer heaven godlike',
#   '\r Looking out of a wreath of fern and cloud puffs.',
#   'Once, when trying with chin against a well-curb,',
#   '\r I discerned, as I thought, beyond the picture,',
#   '\r Through the picture, a something white, uncertain,',
#   '\r Something more of the depths—and then I lost it.',
#   '\r Water came to rebuke the too clear water.',
#   '\r One drop fell from a fern, and lo, a ripple',
#   '\r Shook whatever it was lay there at bottom,',
#   '\r Blurred it, blotted it out. What was that whiteness?',
#   '\r Truth? A pebble of quartz? For once, then, something.'],
#  ['Why make so much of fragmentary blue',
#   '\r In here and there a bird, or butterfly,',
#   '\r Or flower, or wearing-stone, or open eye,',
#   '\r When heaven presents in sheets the solid hue?',
#   '\r \xa0',
#   '\r Since earth is earth, perhaps, not heaven (as yet)—',
#   '\r Though some savants make earth include the sky;',
#   '\r And blue so far above us comes so high,',
#   '\r It only gives our wish for blue a whet.',
#   '\r \xa0',
#   ''],
#  ['Spades take up leaves',
#   '\r No better than spoons,',
#   '\r And bags full of leaves',
#   '\r Are light as balloons.',
#   '\r \xa0',
#   '\r I make a great noise',
#   '\r Of rustling all day',
#   '\r Like rabbit and deer',
#   '\r Running away.',
#   '\r \xa0',
#   '\r But the mountains I raise',
#   '\r Elude my embrace,',
#   '\r Flowing over my arms',
#   '\r And into my face.',
#   '\r \xa0',
#   '\r I may load and unload',
#   '\r Again and again',
#   '\r Till I fill the whole shed,',
#   '\r And what have I then?',
#   '\r \xa0',
#   '\r Next to nothing for weight,',
#   '\r And since they grew duller',
#   '\r From contact with earth,',
#   '\r Next to nothing for color.',
#   '\r \xa0',
#   '\r Next to nothing for use,',
#   '\r But a crop is a crop,',
#   '\r And who’s to say where',
#   '\r The harvest shall stop?',
#   '\r \xa0',
#   ''],
#  ['This saying good-by on the edge of the dark',
#   '\r And the cold to an orchard so young in the bark',
#   '\r Reminds me of all that can happen to harm',
#   '\r An orchard away at the end of the farm',
#   '\r All winter, cut off by a hill from the house.',
#   "\r I don't want it girdled by rabbit and mouse,",
#   "\r I don't want it dreamily nibbled for browse",
#   "\r By deer, and I don't want it budded by grouse.",
#   "\r (If certain it wouldn't be idle to call",
#   "\r I'd summon grouse, rabbit, and deer to the wall",
#   '\r And warn them away with a stick for a gun.)',
#   "\r I don't want it stirred by the heat of the sun.",
#   '\r (We made it secure against being, I hope,',
#   '\r By setting it out on a northerly slope.)',
#   "\r No orchard's the worse for the wintriest storm;",
#   "\r But one thing about it, it mustn't get warm.",
#   '\r "How often already you\'ve had to be told,',
#   '\r Keep cold, young orchard. Good-by and keep cold.',
#   '\r Dread fifty above more than fifty below."',
#   '\r I have to be gone for a season or so.',
#   '\r My business awhile is with different trees,',
#   '\r Less carefully nourished, less fruitful than these,',
#   '\r And such as is done to their wood with an ax—',
#   '\r Maples and birches and tamaracks.',
#   '\r I wish I could promise to lie in the night',
#   "\r And think of an orchard's arboreal plight",
#   '\r When slowly (and nobody comes with a light)',
#   '\r Its heart sinks lower under the sod.',
#   '\r But something has to be left to God.',
#   ''],
#  ['He saw her from the bottom of the stairs',
#   'Before she saw him. She was starting down,',
#   'Looking back over her shoulder at some fear.',
#   'She took a doubtful step and then undid it',
#   'To raise herself and look again. He spoke',
#   'Advancing toward her: ‘What is it you see',
#   'From up there always—for I want to know.’',
#   'She turned and sank upon her skirts at that,',
#   'And her face changed from terrified to dull.',
#   'He said to gain time: ‘What is it you see,’',
#   'Mounting until she cowered under him.',
#   '‘I will find out now—you must tell me, dear.’',
#   'She, in her place, refused him any help',
#   'With the least stiffening of her neck and silence.',
#   'She let him look, sure that he wouldn’t see,',
#   'Blind creature; and awhile he didn’t see.',
#   'But at last he murmured, ‘Oh,’ and again, ‘Oh.’',
#   '',
#   '‘What is it—what?’ she said.',
#   '',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0 \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0 ‘Just that I see.’',
#   '',
#   '‘You don’t,’ she challenged. ‘Tell me what it is.’',
#   '',
#   '‘The wonder is I didn’t see at once.',
#   'I never noticed it from here before.',
#   'I must be wonted to it—that’s the reason.',
#   'The little graveyard where my people are!',
#   'So small the window frames the whole of it.',
#   'Not so much larger than a bedroom, is it?',
#   'There are three stones of slate and one of marble,',
#   'Broad-shouldered little slabs there in the sunlight',
#   'On the sidehill. We haven’t to mind those.',
#   'But I understand: it is not the stones,',
#   'But the child’s mound—’',
#   '',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ‘Don’t, don’t, don’t, don’t,’ she cried.',
#   '',
#   'She withdrew shrinking from beneath his arm',
#   'That rested on the banister, and slid downstairs;',
#   'And turned on him with such a daunting look,',
#   'He said twice over before he knew himself:',
#   '‘Can’t a man speak of his own child he’s lost?’',
#   '',
#   '‘Not you! Oh, where’s my hat? Oh, I don’t need it!',
#   'I must get out of here. I must get air.',
#   'I don’t know rightly whether any man can.’',
#   '',
#   '‘Amy! Don’t go to someone else this time.',
#   'Listen to me. I won’t come down the stairs.’',
#   'He sat and fixed his chin between his fists.',
#   '‘There’s something I should like to ask you, dear.’',
#   '',
#   '‘You don’t know how to ask it.’',
#   '',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ‘Help me, then.’',
#   '',
#   'Her fingers moved the latch for all reply.',
#   '',
#   '‘My words are nearly always an offense.',
#   'I don’t know how to speak of anything',
#   'So as to please you. But I might be taught',
#   'I should suppose. I can’t say I see how.',
#   'A man must partly give up being a man',
#   'With women-folk. We could have some arrangement',
#   'By which I’d bind myself to keep hands off',
#   'Anything special you’re a-mind to name.',
#   'Though I don’t like such things ’twixt those that love.',
#   'Two that don’t love can’t live together without them.',
#   'But two that do can’t live together with them.’',
#   'She moved the latch a little. ‘Don’t—don’t go.',
#   'Don’t carry it to someone else this time.',
#   'Tell me about it if it’s something human.',
#   'Let me into your grief. I’m not so much',
#   'Unlike other folks as your standing there',
#   'Apart would make me out. Give me my chance.',
#   'I do think, though, you overdo it a little.',
#   'What was it brought you up to think it the thing',
#   'To take your mother-loss of a first child',
#   'So inconsolably—in the face of love.',
#   'You’d think his memory might be satisfied—’',
#   '',
#   '‘There you go sneering now!’',
#   '',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ‘I’m not, I’m not!',
#   'You make me angry. I’ll come down to you.',
#   'God, what a woman! And it’s come to this,',
#   'A man can’t speak of his own child that’s dead.’',
#   '',
#   "‘You can’t because you don't know how to speak.",
#   'If you had any feelings, you that dug',
#   'With your own hand—how could you?—his little grave;',
#   'I saw you from that very window there,',
#   'Making the gravel leap and leap in air,',
#   'Leap up, like that, like that, and land so lightly',
#   'And roll back down the mound beside the hole.',
#   'I thought, Who is that man? I didn’t know you.',
#   'And I crept down the stairs and up the stairs',
#   'To look again, and still your spade kept lifting.',
#   'Then you came in. I heard your rumbling voice',
#   'Out in the kitchen, and I don’t know why,',
#   'But I went near to see with my own eyes.',
#   'You could sit there with the stains on your shoes',
#   'Of the fresh earth from your own baby’s grave',
#   'And talk about your everyday concerns.',
#   'You had stood the spade up against the wall',
#   'Outside there in the entry, for I saw it.’',
#   '',
#   '‘I shall laugh the worst laugh I ever laughed.',
#   'I’m cursed. God, if I don’t believe I’m cursed.’',
#   '',
#   '‘I can repeat the very words you were saying:',
#   '“Three foggy mornings and one rainy day',
#   'Will rot the best birch fence a man can build.”',
#   'Think of it, talk like that at such a time!',
#   'What had how long it takes a birch to rot',
#   'To do with what was in the darkened parlor?',
#   'You couldn’t care! The nearest friends can go',
#   'With anyone to death, comes so far short',
#   'They might as well not try to go at all.',
#   'No, from the time when one is sick to death,',
#   'One is alone, and he dies more alone.',
#   'Friends make pretense of following to the grave,',
#   'But before one is in it, their minds are turned',
#   'And making the best of their way back to life',
#   'And living people, and things they understand.',
#   'But the world’s evil. I won’t have grief so',
#   'If I can change it. Oh, I won’t, I won’t!’',
#   '',
#   '‘There, you have said it all and you feel better.',
#   'You won’t go now. You’re crying. Close the door.',
#   'The heart’s gone out of it: why keep it up.',
#   'Amy! There’s someone coming down the road!’',
#   '',
#   '‘You—oh, you think the talk is all. I must go—',
#   'Somewhere out of this house. How can I make you—’',
#   '',
#   '‘If—you—do!’ She was opening the door wider.',
#   '‘Where do you mean to go?\xa0 First tell me that.',
#   'I’ll follow and bring you back by force.\xa0 I will!—’',
#   ''],
#  ['The living come with grassy tread',
#   '\r To read the gravestones on the hill;',
#   '\r The graveyard draws the living still,',
#   '\r But never any more the dead.',
#   '\r \xa0',
#   '\r The verses in it say and say:',
#   '\r ‘The ones who living come today',
#   '\r To read the stones and go away',
#   '\r Tomorrow dead will come to stay.’',
#   '\r \xa0',
#   '\r So sure of death the marbles rhyme,',
#   '\r Yet can’t help marking all the time',
#   '\r How no one dead will seem to come.',
#   '\r What is it men are shrinking from?',
#   '\r \xa0',
#   '\r It would be easy to be clever',
#   '\r And tell the stones: Men hate to die',
#   '\r And have stopped dying now forever.',
#   '\r I think they would believe the lie.',
#   '\r \xa0',
#   ''],
#  ['A Stranger came to the door at eve, ',
#   '\xa0\xa0 And he spoke the bridegroom fair. ',
#   'He bore a green-white stick in his hand, ',
#   '\xa0\xa0 And, for all burden, care. ',
#   'He asked with the eyes more than the lips ',
#   '\xa0\xa0 For a shelter for the night, ',
#   'And he turned and looked at the road afar ',
#   '\xa0\xa0 Without a window light. ',
#   '',
#   'The bridegroom came forth into the porch ',
#   '\xa0\xa0 With, ‘Let us look at the sky, ',
#   'And question what of the night to be, ',
#   '\xa0\xa0 Stranger, you and I.’',
#   'The woodbine leaves littered the yard, ',
#   '\xa0\xa0 The woodbine berries were blue, ',
#   'Autumn, yes, winter was in the wind; ',
#   '\xa0\xa0 ‘Stranger, I wish I knew.’',
#   '',
#   'Within, the bride in the dusk alone ',
#   '\xa0\xa0 Bent over the open fire, ',
#   'Her face rose-red with the glowing coal ',
#   '\xa0\xa0 And the thought of the heart’s desire. ',
#   'The bridegroom looked at the weary road, ',
#   '\xa0\xa0 Yet saw but her within, ',
#   'And wished her heart in a case of gold ',
#   '\xa0\xa0 And pinned with a silver pin. ',
#   '',
#   'The bridegroom thought it little to give ',
#   '\xa0\xa0 A dole of bread, a purse, ',
#   'A heartfelt prayer for the poor of God, ',
#   '\xa0\xa0 Or for the rich a curse; ',
#   'But whether or not a man was asked ',
#   '\xa0\xa0 To mar the love of two ',
#   'By harboring woe in the bridal house, ',
#   '\xa0\xa0 The bridegroom wished he knew.',
#   '',
#   ''],
#  ['',
#   "\r Something there is that doesn't love a wall,",
#   '\r That sends the frozen-ground-swell under it,',
#   '\r And spills the upper boulders in the sun;',
#   '\r And makes gaps even two can pass abreast.',
#   '\r The work of hunters is another thing:',
#   '\r I have come after them and made repair',
#   '\r Where they have left not one stone on a stone,',
#   '\r But they would have the rabbit out of hiding,',
#   '\r To please the yelping dogs. The gaps I mean,',
#   '\r No one has seen them made or heard them made,',
#   '\r But at spring mending-time we find them there.',
#   '\r I let my neighbour know beyond the hill;',
#   '\r And on a day we meet to walk the line',
#   '\r And set the wall between us once again.',
#   '\r We keep the wall between us as we go.',
#   '\r To each the boulders that have fallen to each.',
#   '\r And some are loaves and some so nearly balls',
#   '\r We have to use a spell to make them balance:',
#   '\r "Stay where you are until our backs are turned!"',
#   '\r We wear our fingers rough with handling them.',
#   '\r Oh, just another kind of out-door game,',
#   '\r One on a side. It comes to little more:',
#   '\r There where it is we do not need the wall:',
#   '\r He is all pine and I am apple orchard.',
#   '\r My apple trees will never get across',
#   '\r And eat the cones under his pines, I tell him.',
#   '\r He only says, "Good fences make good neighbours."',
#   '\r Spring is the mischief in me, and I wonder',
#   '\r If I could put a notion in his head:',
#   '"Why do they make good neighbours? Isn\'t it',
#   '\r Where there are cows? But here there are no cows.',
#   "\r Before I built a wall I'd ask to know",
#   '\r What I was walling in or walling out,',
#   '\r And to whom I was like to give offence.',
#   "\r Something there is that doesn't love a wall,",
#   '\r That wants it down." I could say "Elves" to him,',
#   "\r But it's not elves exactly, and I'd rather",
#   '\r He said it for himself. I see him there',
#   '\r Bringing a stone grasped firmly by the top',
#   '\r In each hand, like an old-stone savage armed.',
#   '\r He moves in darkness as it seems to me,',
#   '\r Not of woods only and the shade of trees.',
#   "\r He will not go behind his father's saying,",
#   '\r And he likes having thought of it so well',
#   '\r He says again, "Good fences make good neighbours."'],
#  ['There was never a sound beside the wood but one,',
#   'And that was my long scythe whispering to the ground.',
#   'What was it it whispered? I knew not well myself;',
#   'Perhaps it was something about the heat of the sun,',
#   'Something, perhaps, about the lack of sound—',
#   'And that was why it whispered and did not speak.',
#   'It was no dream of the gift of idle hours,',
#   'Or easy gold at the hand of fay or elf:',
#   'Anything more than the truth would have seemed too weak',
#   'To the earnest love that laid the swale in rows,',
#   'Not without feeble-pointed spikes of flowers',
#   '(Pale orchises), and scared a bright green snake.',
#   'The fact is the sweetest dream that labor knows.',
#   'My long scythe whispered and left the hay to make.',
#   ''],
#  ['They sent him back to her. The letter came',
#   '\r Saying . . . And she could have him. And before',
#   '\r She could be sure there was no hidden ill',
#   '\r Under the formal writing, he was there,',
#   '\r Living. They gave him back to her alive—',
#   '\r How else? They are not known to send the dead—',
#   '\r And not disfigured visibly. His face?',
#   '\r His hands? She had to look, and ask,',
#   '\r ‘What was it, dear?’ And she had given all',
#   '\r And still she had all—they had—they the lucky!',
#   '\r Wasn’t she glad now? Everything seemed won,',
#   '\r And all the rest for them permissible ease.',
#   '\r She had to ask, ‘What was it, dear?’',
#   '\r \xa0',
#   '\r  ‘Enough',
#   '\r Yet not enough. A bullet through and through,',
#   '\r High in the breast. Nothing but what good care',
#   '\r And medicine and rest, and you a week,',
#   '\r Can cure me of to go again.’ The same',
#   '\r Grim giving to do over for them both.',
#   '\r She dared no more than ask him with her eyes',
#   '\r How was it with him for a second trial.',
#   '\r And with his eyes he asked her not to ask.',
#   '\r They had given him back to her, but not to keep.',
#   '\r \xa0',
#   ''],
#  ['Nature’s first green is gold,',
#   '\r Her hardest hue to hold.',
#   '\r Her early leaf’s a flower;',
#   '\r But only so an hour.',
#   '\r Then leaf subsides to leaf.',
#   '\r So Eden sank to grief,',
#   '\r So dawn goes down to day.',
#   '\r Nothing gold can stay.',
#   '\r \xa0',
#   ''],
#  ['The battle rent a cobweb diamond-strung\r',
#   "And cut a flower beside a ground bird's nest\r",
#   'Before it stained a single human breast.\r',
#   'The stricken flower bent double and so hung.\r',
#   'And still the bird revisited her young.\r',
#   'A butterfly its fall had dispossessed\r',
#   'A moment sought in air his flower of rest,\r',
#   'Then lightly stooped to it and fluttering clung.\r',
#   '',
#   'On the bare upland pasture there had spread\r',
#   "O'ernight 'twixt mullein stalks a wheel of thread\r",
#   'And straining cables wet with silver dew.\r',
#   'A sudden passing bullet shook it dry.\r',
#   'The indwelling spider ran to greet the fly,\r',
#   'But finding nothing, sullenly withdrew.\r',
#   '',
#   ''],
#  ['Out through the fields and the woods',
#   '\xa0\xa0 And over the walls I have wended;',
#   'I have climbed the hills of view',
#   '\xa0\xa0 And looked at the world, and descended;',
#   'I have come by the highway home,',
#   '\xa0\xa0 And lo, it is ended.',
#   '\xa0',
#   'The leaves are all dead on the ground,',
#   '\xa0\xa0 Save those that the oak is keeping',
#   'To ravel them one by one',
#   '\xa0\xa0 And let them go scraping and creeping',
#   'Out over the crusted snow,',
#   '\xa0\xa0 When others are sleeping.',
#   '\xa0',
#   'And the dead leaves lie huddled and still,',
#   '\xa0\xa0 No longer blown hither and thither;',
#   'The last lone aster is gone;',
#   '\xa0\xa0 The flowers of the witch hazel wither;',
#   'The heart is still aching to seek,',
#   '\xa0\xa0 But the feet question ‘Whither?’',
#   '\xa0',
#   'Ah, when to the heart of man',
#   '\xa0\xa0 Was it ever less than a treason',
#   'To go with the drift of things,',
#   '\xa0\xa0 To yield with a grace to reason,',
#   'And bow and accept the end',
#   '\xa0\xa0 Of a love or a season?',
#   ''],
#  ['Whose woods these are I think I know.\xa0\xa0\xa0',
#   '\r His house is in the village though;\xa0\xa0\xa0',
#   '\r He will not see me stopping here\xa0\xa0\xa0',
#   '\r To watch his woods fill up with snow.\xa0\xa0\xa0',
#   '',
#   '\r My little horse must think it queer\xa0\xa0\xa0',
#   '\r To stop without a farmhouse near\xa0\xa0\xa0',
#   '\r Between the woods and frozen lake\xa0\xa0\xa0',
#   '\r The darkest evening of the year.\xa0\xa0\xa0',
#   '',
#   '\r He gives his harness bells a shake\xa0\xa0\xa0',
#   '\r To ask if there is some mistake.\xa0\xa0\xa0',
#   '\r The only other sound’s the sweep\xa0\xa0\xa0',
#   '\r Of easy wind and downy flake.\xa0\xa0\xa0',
#   '',
#   '\r The woods are lovely, dark and deep, \xa0\xa0',
#   '\r But I have promises to keep,\xa0\xa0\xa0',
#   '\r And miles to go before I sleep,\xa0\xa0\xa0',
#   '\r And miles to go before I sleep.',
#   ''],
#  ['Before man came to blow it right',
#   '\r \xa0\xa0\xa0\xa0 The wind once blew itself untaught,',
#   '\r And did its loudest day and night',
#   '\r \xa0\xa0\xa0\xa0 In any rough place where it caught.',
#   '\r \xa0',
#   '\r Man came to tell it what was wrong:',
#   '\r \xa0\xa0\xa0\xa0 It hadn’t found the place to blow;',
#   '\r It blew too hard—the aim was song.',
#   '\r \xa0\xa0\xa0\xa0 And listen—how it ought to go!',
#   '\r \xa0',
#   '\r He took a little in his mouth,',
#   '\r \xa0\xa0\xa0\xa0 And held it long enough for north',
#   '\r To be converted into south,',
#   '\r \xa0\xa0\xa0\xa0 And then by measure blew it forth.',
#   '\r \xa0',
#   '\r By measure. It was word and note,',
#   '\r \xa0\xa0\xa0\xa0 The wind the wind had meant to be—',
#   '\r A little through the lips and throat.',
#   '\r \xa0\xa0\xa0\xa0 The aim was song—the wind could see.',
#   '\r \xa0',
#   ''],
#  ['I came an errand one cloud-blowing evening',
#   '\r To a slab-built, black-paper-covered house',
#   '\r Of one room and one window and one door,',
#   '\r The only dwelling in a waste cut over',
#   '\r A hundred square miles round it in the mountains:',
#   '\r And that not dwelt in now by men or women.',
#   '\r (It never had been dwelt in, though, by women,',
#   '\r So what is this I make a sorrow of?)',
#   '\r I came as census-taker to the waste',
#   '\r To count the people in it and found none,',
#   '\r None in the hundred miles, none in the house,',
#   '\r Where I came last with some hope, but not much,',
#   '\r After hours’ overlooking from the cliffs',
#   '\r An emptiness flayed to the very stone.',
#   '\r I found no people that dared show themselves,',
#   '\r None not in hiding from the outward eye.',
#   '\r The time was autumn, but how anyone',
#   '\r Could tell the time of year when every tree',
#   '\r That could have dropped a leaf was down itself',
#   '\r And nothing but the stump of it was left',
#   '\r Now bringing out its rings in sugar of pitch;',
#   '\r And every tree up stood a rotting trunk',
#   '\r Without a single leaf to spend on autumn,',
#   '\r Or branch to whistle after what was spent.',
#   '\r Perhaps the wind the more without the help',
#   '\r Of breathing trees said something of the time',
#   '\r Of year or day the way it swung a door',
#   '\r Forever off the latch, as if rude men',
#   '\r Passed in and slammed it shut each one behind him',
#   '\r For the next one to open for himself.',
#   '\r I counted nine I had no right to count',
#   '\r (But this was dreamy unofficial counting)',
#   '\r Before I made the tenth across the threshold.',
#   '\r Where was my supper? Where was anyone’s?',
#   '\r No lamp was lit. Nothing was on the table.',
#   '\r The stove was cold—the stove was off the chimney—',
#   '\r And down by one side where it lacked a leg.',
#   '\r The people that had loudly passed the door',
#   '\r Were people to the ear but not the eye.',
#   '\r They were not on the table with their elbows.',
#   '\r They were not sleeping in the shelves of bunks.',
#   '\r I saw no men there and no bones of men there.',
#   '\r I armed myself against such bones as might be',
#   '\r With the pitch-blackened stub of an ax-handle',
#   '\r I picked up off the straw-dust covered floor.',
#   '\r Not bones, but the ill-fitted window rattled.',
#   '\r The door was still because I held it shut',
#   '\r While I thought what to do that could be done—',
#   '\r About the house—about the people not there.',
#   '\r This house in one year fallen to decay',
#   '\r Filled me with no less sorrow than the houses',
#   '\r Fallen to ruin in ten thousand years',
#   '\r Where Asia wedges Africa from Europe.',
#   '\r Nothing was left to do that I could see',
#   '\r Unless to find that there was no one there',
#   '\r And declare to the cliffs too far for echo,',
#   '\r “The place is desert, and let whoso lurks',
#   '\r In silence, if in this he is aggrieved,',
#   '\r Break silence now or be forever silent.',
#   '\r Let him say why it should not be declared so.”',
#   '\r The melancholy of having to count souls',
#   '\r Where they grow fewer and fewer every year',
#   '\r Is extreme where they shrink to none at all.',
#   '\r It must be I want life to go on living.\xa0',
#   ''],
#  ['Mary sat musing on the lamp-flame at the table ',
#   'Waiting for Warren. When she heard his step, ',
#   'She ran on tip-toe down the darkened passage ',
#   'To meet him in the doorway with the news ',
#   'And put him on his guard. ‘Silas is back.’',
#   'She pushed him outward with her through the door ',
#   'And shut it after her. ‘Be kind,’ she said. ',
#   'She took the market things from Warren’s arms ',
#   'And set them on the porch, then drew him down ',
#   'To sit beside her on the wooden steps. ',
#   '',
#   '‘When was I ever anything but kind to him? ',
#   'But I’ll not have the fellow back,’ he said. ',
#   '‘I told him so last haying, didn’t I? ',
#   'If he left then, I said, that ended it. ',
#   'What good is he? Who else will harbor him ',
#   'At his age for the little he can do? ',
#   'What help he is there’s no depending on. ',
#   'Off he goes always when I need him most. ',
#   'He thinks he ought to earn a little pay, ',
#   'Enough at least to buy tobacco with, ',
#   'So he won’t have to beg and be beholden.',
#   '“All right,” I say, “I can’t afford to pay ',
#   'Any fixed wages, though I wish I could.”',
#   '“Someone else can.” “Then someone else will have to.”',
#   'I shouldn’t mind his bettering himself ',
#   'If that was what it was. You can be certain, ',
#   'When he begins like that, there’s someone at him ',
#   'Trying to coax him off with pocket-money,— ',
#   'In haying time, when any help is scarce. ',
#   'In winter he comes back to us. I’m done.’ ',
#   '',
#   '‘Sh! not so loud: he’ll hear you,’ Mary said. ',
#   '',
#   '‘I want him to: he’ll have to soon or late.’ ',
#   '',
#   '‘He’s worn out. He’s asleep beside the stove. ',
#   'When I came up from Rowe’s I found him here, ',
#   'Huddled against the barn-door fast asleep, ',
#   'A miserable sight, and frightening, too— ',
#   'You needn’t smile—I didn’t recognize him— ',
#   'I wasn’t looking for him—and he’s changed. ',
#   'Wait till you see.’ ',
#   '',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ‘Where did you say he’d been?’ ',
#   '',
#   '‘He didn’t say. I dragged him to the house, ',
#   'And gave him tea and tried to make him smoke. ',
#   'I tried to make him talk about his travels. ',
#   'Nothing would do: he just kept nodding off.’ ',
#   '',
#   '‘What did he say? Did he say anything?’ ',
#   '',
#   '‘But little.’ ',
#   '',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ‘Anything? Mary, confess ',
#   'He said he’d come to ditch the meadow for me.’',
#   '',
#   '‘Warren!’ ',
#   '',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ‘But did he? I just want to know.’ ',
#   '',
#   '‘Of course he did. What would you have him say? ',
#   'Surely you wouldn’t grudge the poor old man ',
#   'Some humble way to save his self-respect. ',
#   'He added, if you really care to know, ',
#   'He meant to clear the upper pasture, too. ',
#   'That sounds like something you have heard before? ',
#   'Warren, I wish you could have heard the way ',
#   'He jumbled everything. I stopped to look ',
#   'Two or three times—he made me feel so queer— ',
#   'To see if he was talking in his sleep. ',
#   'He ran on Harold Wilson—you remember— ',
#   'The boy you had in haying four years since. ',
#   'He’s finished school, and teaching in his college. ',
#   'Silas declares you’ll have to get him back. ',
#   'He says they two will make a team for work: ',
#   'Between them they will lay this farm as smooth! ',
#   'The way he mixed that in with other things. ',
#   'He thinks young Wilson a likely lad, though daft ',
#   'On education—you know how they fought ',
#   'All through July under the blazing sun, ',
#   'Silas up on the cart to build the load, ',
#   'Harold along beside to pitch it on.’ ',
#   '',
#   '‘Yes, I took care to keep well out of earshot.’ ',
#   '',
#   '‘Well, those days trouble Silas like a dream. ',
#   'You wouldn’t think they would. How some things linger! ',
#   'Harold’s young college boy’s assurance piqued him. ',
#   'After so many years he still keeps finding ',
#   'Good arguments he sees he might have used. ',
#   'I sympathize. I know just how it feels ',
#   'To think of the right thing to say too late. ',
#   'Harold’s associated in his mind with Latin. ',
#   'He asked me what I thought of Harold’s saying ',
#   'He studied Latin like the violin ',
#   'Because he liked it—that an argument! ',
#   'He said he couldn’t make the boy believe ',
#   'He could find water with a hazel prong— ',
#   'Which showed how much good school had ever done him. ',
#   'He wanted to go over that. But most of all ',
#   'He thinks if he could have another chance ',
#   'To teach him how to build a load of hay—’ ',
#   '',
#   '‘I know, that’s Silas’ one accomplishment. ',
#   'He bundles every forkful in its place, ',
#   'And tags and numbers it for future reference, ',
#   'So he can find and easily dislodge it ',
#   'In the unloading. Silas does that well. ',
#   'He takes it out in bunches like big birds’ nests. ',
#   'You never see him standing on the hay ',
#   'He’s trying to lift, straining to lift himself.’ ',
#   '',
#   '‘He thinks if he could teach him that, he’d be ',
#   'Some good perhaps to someone in the world. ',
#   'He hates to see a boy the fool of books. ',
#   'Poor Silas, so concerned for other folk, ',
#   'And nothing to look backward to with pride, ',
#   'And nothing to look forward to with hope, ',
#   'So now and never any different.’ ',
#   '',
#   'Part of a moon was falling down the west, ',
#   'Dragging the whole sky with it to the hills. ',
#   'Its light poured softly in her lap. She saw it',
#   'And spread her apron to it. She put out her hand ',
#   'Among the harp-like morning-glory strings, ',
#   'Taut with the dew from garden bed to eaves, ',
#   'As if she played unheard some tenderness ',
#   'That wrought on him beside her in the night. ',
#   '‘Warren,’ she said, ‘he has come home to die: ',
#   'You needn’t be afraid he’ll leave you this time.’ ',
#   '',
#   '‘Home,’ he mocked gently. ',
#   '',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ‘Yes, what else but home? ',
#   'It all depends on what you mean by home. ',
#   'Of course he’s nothing to us, any more ',
#   'Than was the hound that came a stranger to us ',
#   'Out of the woods, worn out upon the trail.’ ',
#   '',
#   '‘Home is the place where, when you have to go there, ',
#   'They have to take you in.’ ',
#   '',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ‘I should have called it ',
#   'Something you somehow haven’t to deserve.’ ',
#   '',
#   'Warren leaned out and took a step or two, ',
#   'Picked up a little stick, and brought it back ',
#   'And broke it in his hand and tossed it by. ',
#   '‘Silas has better claim on us you think ',
#   'Than on his brother? Thirteen little miles ',
#   'As the road winds would bring him to his door. ',
#   'Silas has walked that far no doubt today. ',
#   'Why didn’t he go there? His brother’s rich, ',
#   'A somebody—director in the bank.’ ',
#   '',
#   '‘He never told us that.’ ',
#   '',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ‘We know it though.’ ',
#   '',
#   '‘I think his brother ought to help, of course. ',
#   'I’ll see to that if there is need. He ought of right ',
#   'To take him in, and might be willing to— ',
#   'He may be better than appearances. ',
#   'But have some pity on Silas. Do you think ',
#   'If he’d had any pride in claiming kin ',
#   'Or anything he looked for from his brother, ',
#   'He’d keep so still about him all this time?’ ',
#   '',
#   '‘I wonder what’s between them.’ ',
#   '',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ‘I can tell you. ',
#   'Silas is what he is—we wouldn’t mind him— ',
#   'But just the kind that kinsfolk can’t abide. ',
#   'He never did a thing so very bad. ',
#   'He don’t know why he isn’t quite as good ',
#   'As anyone. Worthless though he is,',
#   'He won’t be made ashamed to please his brother.’ ',
#   '',
#   '‘I can’t think Si ever hurt anyone.’ ',
#   '',
#   '‘No, but he hurt my heart the way he lay ',
#   'And rolled his old head on that sharp-edged chair-back. ',
#   'He wouldn’t let me put him on the lounge. ',
#   'You must go in and see what you can do. ',
#   'I made the bed up for him there tonight. ',
#   'You’ll be surprised at him—how much he’s broken. ',
#   "His working days are done; I'm sure of it.’ ",
#   '',
#   '‘I’d not be in a hurry to say that.’ ',
#   '',
#   '‘I haven’t been. Go, look, see for yourself. ',
#   'But, Warren, please remember how it is: ',
#   'He’s come to help you ditch the meadow. ',
#   'He has a plan. You mustn’t laugh at him. ',
#   'He may not speak of it, and then he may. ',
#   'I’ll sit and see if that small sailing cloud ',
#   'Will hit or miss the moon.’ ',
#   '',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 It hit the moon. ',
#   'Then there were three there, making a dim row, ',
#   'The moon, the little silver cloud, and she. ',
#   '',
#   'Warren returned—too soon, it seemed to her, ',
#   'Slipped to her side, caught up her hand and waited. ',
#   '',
#   '‘Warren,’ she questioned. ',
#   '',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ‘Dead,’ was all he answered.',
#   '',
#   ''],
#  ['The land was ours before we were the land’s.',
#   'She was our land more than a hundred years',
#   'Before we were her people. She was ours',
#   'In Massachusetts, in Virginia,',
#   'But we were England’s, still colonials,',
#   'Possessing what we still were unpossessed by,',
#   'Possessed by what we now no more possessed.',
#   'Something we were withholding made us weak',
#   'Until we found out that it was ourselves',
#   'We were withholding from our land of living,',
#   'And forthwith found salvation in surrender.',
#   'Such as we were we gave ourselves outright',
#   '(The deed of gift was many deeds of war)',
#   'To the land vaguely realizing westward,',
#   'But still unstoried, artless, unenhanced,',
#   'Such as she was, such as she would become.',
#   '',
#   ''],
#  ['The house had gone to bring again',
#   '\r To the midnight sky a sunset glow.',
#   '\r Now the chimney was all of the house that stood,',
#   '\r Like a pistil after the petals go.',
#   '\r \xa0',
#   '\r The barn opposed across the way,',
#   '\r That would have joined the house in flame',
#   '\r Had it been the will of the wind, was left',
#   '\r To bear forsaken the place’s name.',
#   '\r \xa0',
#   '\r No more it opened with all one end',
#   '\r For teams that came by the stony road',
#   '\r To drum on the floor with scurrying hoofs',
#   '\r And brush the mow with the summer load.',
#   '\r \xa0',
#   '\r The birds that came to it through the air',
#   '\r At broken windows flew out and in,',
#   '\r Their murmur more like the sigh we sigh',
#   '\r From too much dwelling on what has been.',
#   '\r \xa0',
#   '\r Yet for them the lilac renewed its leaf,',
#   '\r And the aged elm, though touched with fire;',
#   '\r And the dry pump flung up an awkward arm;',
#   '\r And the fence post carried a strand of wire.',
#   '',
#   '\r For them there was really nothing sad.',
#   '\r But though they rejoiced in the nest they kept,',
#   '\r One had to be versed in country things',
#   '\r Not to believe the phoebes wept.',
#   ''],
#  ['',
#   'There is a singer everyone has heard,',
#   'Loud, a mid-summer and a mid-wood bird,',
#   'Who makes the solid tree trunks sound again.',
#   'He says that leaves are old and that for flowers',
#   'Mid-summer is to spring as one to ten.',
#   'He says the early petal-fall is past',
#   'When pear and cherry bloom went down in showers',
#   'On sunny days a moment overcast;',
#   'And comes that other fall we name the fall.',
#   'He says the highway dust is over all.',
#   'The bird would cease and be as other birds',
#   'But that he knows in singing not to sing.',
#   'The question that he frames in all but words',
#   'Is what to make of a diminished thing.',
#   ''],
#  ["I'm going out to clean the pasture spring;\r",
#   "I'll only stop to rake the leaves away\r",
#   '(And wait to watch the water clear, I may):\r',
#   "I sha'n't be gone long.—You come too.\r",
#   '',
#   "I'm going out to fetch the little calf\r",
#   "That's standing by the mother. It's so young,\r",
#   'It totters when she licks it with her tongue.\r',
#   "I sha'n't be gone long.—You come too.\r",
#   '',
#   ''],
#  ['Two roads diverged in a yellow wood,',
#   '\r And sorry I could not travel both',
#   '\r And be one traveler, long I stood',
#   '\r And looked down one as far as I could',
#   '\r To where it bent in the undergrowth;',
#   '',
#   '\r Then took the other, as just as fair,',
#   '\r And having perhaps the better claim,',
#   '\r Because it was grassy and wanted wear;',
#   '\r Though as for that the passing there',
#   '\r Had worn them really about the same,',
#   '',
#   '\r And both that morning equally lay',
#   '\r In leaves no step had trodden black.',
#   '\r Oh, I kept the first for another day!',
#   '\r Yet knowing how way leads on to way,',
#   '\r I doubted if I should ever come back.',
#   '',
#   '\r I shall be telling this with a sigh',
#   '\r Somewhere ages and ages hence:',
#   '\r Two roads diverged in a wood, and I—',
#   '\r I took the one less traveled by,',
#   '\r And that has made all the difference.',
#   ''],
#  ['Once when the snow of the year was beginning to fall,',
#   '\r We stopped by a mountain pasture to say, ‘Whose colt?’',
#   '\r A little Morgan had one forefoot on the wall,',
#   '\r The other curled at his breast. He dipped his head',
#   '\r And snorted at us. And then he had to bolt.',
#   '\r We heard the miniature thunder where he fled,',
#   '\r And we saw him, or thought we saw him, dim and grey,',
#   '\r Like a shadow against the curtain of falling flakes.',
#   '\r ‘I think the little fellow’s afraid of the snow.',
#   '\r He isn’t winter-broken. It isn’t play',
#   '\r With the little fellow at all. He’s running away.',
#   '\r I doubt if even his mother could tell him, “Sakes,',
#   '\r It’s only weather.” He’d think she didn’t know!',
#   '\r Where is his mother? He can’t be out alone.’',
#   '\r And now he comes again with a clatter of stone',
#   '\r And mounts the wall again with whited eyes',
#   "\r And all his tail that isn't hair up straight.",
#   '\r He shudders his coat as if to throw off flies.',
#   '\r ‘Whoever it is that leaves him out so late,',
#   '\r When other creatures have gone to stall and bin,',
#   '\r Ought to be told to come and take him in.’',
#   ''],
#  ['I wonder about the trees.',
#   'Why do we wish to bear',
#   'Forever the noise of these',
#   'More than another noise',
#   'So close to our dwelling place?',
#   'We suffer them by the day',
#   'Till we lose all measure of pace,',
#   'And fixity in our joys,',
#   'And acquire a listening air.',
#   'They are that that talks of going',
#   'But never gets away;',
#   'And that talks no less for knowing,',
#   'As it grows wiser and older,',
#   'That now it means to stay.',
#   'My feet tug at the floor',
#   'And my head sways to my shoulder',
#   'Sometimes when I watch trees sway,',
#   'From the window or the door.',
#   'I shall set forth for somewhere,',
#   'I shall make the reckless choice',
#   'Some day when they are in voice',
#   'And tossing so as to scare',
#   'The white clouds over them on.',
#   'I shall have less to say,',
#   'But I shall be gone.',
#   '',
#   ''],
#  ['"You know Orion always comes up sideways.\r',
#   'Throwing a leg up over our fence of mountains,\r',
#   'And rising on his hands, he looks in on me\r',
#   'Busy outdoors by lantern-light with something\r',
#   'I should have done by daylight, and indeed,\r',
#   'After the ground is frozen, I should have done\r',
#   'Before it froze, and a gust flings a handful\r',
#   'Of waste leaves at my smoky lantern chimney\r',
#   'To make fun of my way of doing things,\r',
#   "Or else fun of Orion's having caught me.\r",
#   'Has a man, I should like to ask, no rights\r',
#   'These forces are obliged to pay respect to?"\r',
#   'So Brad McLaughlin mingled reckless talk\r',
#   'Of heavenly stars with hugger-mugger farming,\r',
#   'Till having failed at hugger-mugger farming,\r',
#   'He burned his house down for the fire insurance\r',
#   'And spent the proceeds on a telescope\r',
#   'To satisfy a lifelong curiosity\r',
#   'About our place among the infinities.\r',
#   '',
#   '"What do you want with one of those blame things?"\r',
#   'I asked him well beforehand. "Don\'t you get one!"\r',
#   '',
#   '"Don\'t call it blamed; there isn\'t anything\r',
#   'More blameless in the sense of being less\r',
#   'A weapon in our human fight," he said.\r',
#   '"I\'ll have one if I sell my farm to buy it."\r',
#   'There where he moved the rocks to plow the ground\r',
#   "And plowed between the rocks he couldn't move,\r",
#   'Few farms changed hands; so rather than spend years\r',
#   'Trying to sell his farm and then not selling,\r',
#   'He burned his house down for the fire insurance\r',
#   'And bought the telescope with what it came to.\r',
#   'He had been heard to say by several:\r',
#   '"The best thing that we\'re put here for\'s to see;\r',
#   "The strongest thing that's given us to see with's\r",
#   'A telescope. Someone in every town\r',
#   'Seems to me owes it to the town to keep one.\r',
#   'In Littleton it may as well be me."\r',
#   'After such loose talk it was no surprise\r',
#   'When he did what he did and burned his house down.\r',
#   '',
#   'Mean laughter went about the town that day\r',
#   "To let him know we weren't the least imposed on,\r",
#   "And he could wait—we'd see to him tomorrow.\r",
#   'But the first thing next morning we reflected\r',
#   'If one by one we counted people out\r',
#   "For the least sin, it wouldn't take us long\r",
#   'To get so we had no one left to live with.\r',
#   'For to be social is to be forgiving.\r',
#   'Our thief, the one who does our stealing from us,\r',
#   "We don't cut off from coming to church suppers,\r",
#   'But what we miss we go to him and ask for.\r',
#   'He promptly gives it back, that is if still\r',
#   'Uneaten, unworn out, or undisposed of.\r',
#   "It wouldn't do to be too hard on Brad\r",
#   'About his telescope. Beyond the age\r',
#   'Of being given one for Christmas gift,\r',
#   'He had to take the best way he knew how\r',
#   'To find himself in one. Well, all we said was\r',
#   'He took a strange thing to be roguish over.\r',
#   'Some sympathy was wasted on the house,\r',
#   'A good old-timer dating back along;\r',
#   "But a house isn't sentient; the house\r",
#   "Didn't feel anything. And if it did,\r",
#   'Why not regard it as a sacrifice,\r',
#   'And an old-fashioned sacrifice by fire,\r',
#   'Instead of a new-fashioned one at auction?\r',
#   '',
#   'Out of a house and so out of a farm\r',
#   'At one stroke (of a match), Brad had to turn\r',
#   'To earn a living on the Concord railroad,\r',
#   'As under-ticket-agent at a station\r',
#   "Where his job, when he wasn't selling tickets,\r",
#   'Was setting out up track and down, not plants\r',
#   'As on a farm, but planets, evening stars\r',
#   'That varied in their hue from red to green.\r',
#   '',
#   'He got a good glass for six hundred dollars.\r',
#   'His new job gave him leisure for stargazing.\r',
#   'Often he bid me come and have a look\r',
#   'Up the brass barrel, velvet black inside,\r',
#   'At a star quaking in the other end.\r',
#   'I recollect a night of broken clouds\r',
#   'And underfoot snow melted down to ice,\r',
#   'And melting further in the wind to mud.\r',
#   'Bradford and I had out the telescope.\r',
#   'We spread our two legs as it spread its three,\r',
#   'Pointed our thoughts the way we pointed it,\r',
#   'And standing at our leisure till the day broke,\r',
#   'Said some of the best things we ever said.\r',
#   'That telescope was christened the Star-Splitter,\r',
#   "Because it didn't do a thing but split\r",
#   'A star in two or three the way you split\r',
#   'A globule of quicksilver in your hand\r',
#   'With one stroke of your finger in the middle.\r',
#   "It's a star-splitter if there ever was one,\r",
#   'And ought to do some good if splitting stars\r',
#   "'Sa thing to be compared with splitting wood.\r",
#   '',
#   "We've looked and looked, but after all where are we?\r",
#   'Do we know any better where we are,\r',
#   'And how it stands between the night tonight\r',
#   'And a man with a smoky lantern chimney?\r',
#   'How different from the way it ever stood?',
#   ''],
#  ['I went to turn the grass once after one',
#   '\r Who mowed it in the dew before the sun.',
#   '\r \xa0',
#   '\r The dew was gone that made his blade so keen',
#   '\r Before I came to view the levelled scene.',
#   '\r \xa0',
#   '\r I looked for him behind an isle of trees;',
#   '\r I listened for his whetstone on the breeze.',
#   '\r \xa0',
#   '\r But he had gone his way, the grass all mown,',
#   '\r And I must be, as he had been,—alone,',
#   '\r \xa0',
#   '\r ‘As all must be,’ I said within my heart,',
#   '\r ‘Whether they work together or apart.’',
#   '\r \xa0',
#   '\r But as I said it, swift there passed me by',
#   '\r On noiseless wing a ‘wildered butterfly,',
#   '\r \xa0',
#   '\r Seeking with memories grown dim o’er night',
#   '\r Some resting flower of yesterday’s delight.',
#   '\r \xa0',
#   '\r And once I marked his flight go round and round,',
#   '\r As where some flower lay withering on the ground.',
#   '\r \xa0',
#   '\r And then he flew as far as eye could see,',
#   '\r And then on tremulous wing came back to me.',
#   '\r \xa0',
#   '\r I thought of questions that have no reply,',
#   '\r And would have turned to toss the grass to dry;',
#   '\r \xa0',
#   '\r But he turned first, and led my eye to look',
#   '\r At a tall tuft of flowers beside a brook,',
#   '\r \xa0',
#   '\r A leaping tongue of bloom the scythe had spared',
#   '\r Beside a reedy brook the scythe had bared.',
#   '\r \xa0',
#   '\r I left my place to know them by their name,',
#   '\r Finding them butterfly weed when I came.',
#   '\r \xa0',
#   '\r The mower in the dew had loved them thus,',
#   '\r By leaving them to flourish, not for us,',
#   '\r \xa0',
#   '\r Nor yet to draw one thought of ours to him.',
#   '\r But from sheer morning gladness at the brim.',
#   '\r \xa0',
#   '\r The butterfly and I had lit upon,',
#   '\r Nevertheless, a message from the dawn,',
#   '\r \xa0',
#   '\r That made me hear the wakening birds around,',
#   '\r And hear his long scythe whispering to the ground,',
#   '\r \xa0',
#   '\r And feel a spirit kindred to my own;',
#   '\r So that henceforth I worked no more alone;',
#   '\r \xa0',
#   '\r But glad with him, I worked as with his aid,',
#   '\r And weary, sought at noon with him the shade;',
#   '\r \xa0',
#   '\r And dreaming, as it were, held brotherly speech',
#   '\r With one whose thought I had not hoped to reach.',
#   '\r \xa0',
#   '\r ‘Men work together,’ I told him from the heart,',
#   '\r ‘Whether they work together or apart.’',
#   '\r \xa0',
#   ''],
#  ['Out walking in the frozen swamp one gray day,\r',
#   "I paused and said, 'I will turn back from here.\r",
#   "No, I will go on farther—and we shall see.'\r",
#   'The hard snow held me, save where now and then\r',
#   'One foot went through. The view was all in lines\r',
#   'Straight up and down of tall slim trees\r',
#   'Too much alike to mark or name a place by\r',
#   'So as to say for certain I was here\r',
#   'Or somewhere else: I was just far from home.\r',
#   'A small bird flew before me. He was careful\r',
#   'To put a tree between us when he lighted,\r',
#   'And say no word to tell me who he was\r',
#   'Who was so foolish as to think what he thought.\r',
#   'He thought that I was after him for a feather—\r',
#   'The white one in his tail; like one who takes\r',
#   'Everything said as personal to himself.\r',
#   'One flight out sideways would have undeceived him.\r',
#   'And then there was a pile of wood for which\r',
#   'I forgot him and let his little fear\r',
#   'Carry him off the way I might have gone,\r',
#   'Without so much as wishing him good-night.\r',
#   'He went behind it to make his last stand.\r',
#   'It was a cord of maple, cut and split\r',
#   'And piled—and measured, four by four by eight.\r',
#   'And not another like it could I see.\r',
#   "No runner tracks in this year's snow looped near it.\r",
#   "And it was older sure than this year's cutting,\r",
#   "Or even last year's or the year's before.\r",
#   'The wood was gray and the bark warping off it\r',
#   'And the pile somewhat sunken. Clematis\r',
#   'Had wound strings round and round it like a bundle.\r',
#   'What held it though on one side was a tree\r',
#   'Still growing, and on one a stake and prop,\r',
#   'These latter about to fall. I thought that only\r',
#   'Someone who lived in turning to fresh tasks\r',
#   'Could so forget his handiwork on which\r',
#   'He spent himself, the labor of his ax,\r',
#   'And leave it there far from a useful fireplace\r',
#   'To warm the frozen swamp as best it could\r',
#   'With the slow smokeless burning of decay.\r',
#   '',
#   ''],
#  ['I slumbered with your poems on my breast',
#   '\r Spread open as I dropped them half-read through',
#   '\r Like dove wings on a figure on a tomb',
#   '\r To see, if in a dream they brought of you,',
#   '',
#   '\r I might not have the chance I missed in life',
#   '\r Through some delay, and call you to your face',
#   '\r First soldier, and then poet, and then both,',
#   '\r Who died a soldier-poet of your race.',
#   '',
#   '\r I meant, you meant, that nothing should remain',
#   '\r Unsaid between us, brother, and this remained—',
#   '\r And one thing more that was not then to say:',
#   '\r The Victory for what it lost and gained.',
#   '',
#   "\r You went to meet the shell's embrace of fire",
#   '\r On Vimy Ridge; and when you fell that day',
#   '\r The war seemed over more for you than me,',
#   '\r But now for me than you—the other way.',
#   '',
#   '\r How over, though, for even me who knew',
#   '\r The foe thrust back unsafe beyond the Rhine,',
#   '\r If I was not to speak of it to you',
#   '\r And see you pleased once more with words of mine?',
#   ''],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %%
# Remove special characters and their adjacent white spaces from each list of strings (lines) in each poem
clean = [[x.strip() for x in i] for i in poem_lines3]

# Remove empty strings from the list of strings in each poem
clean = [[x for x in i if x] for i in clean]

# Stringify the lists of text per poem
clean2 = []
for poem in clean:
    str1 = '\n'.join(poem)
    clean2.append(str1)

# %%
clean2
# Out:
# ['O hushed October morning mild,\nThy leaves have ripened to the fall;\nTomorrow’s wind, if it be wild,\nShould waste them all.\nThe crows above the forest call;\nTomorrow they may form and go.\nO hushed October morning mild,\nBegin the hours of this day slow.\nMake the day seem to us less brief.\nHearts not averse to being beguiled,\nBeguile us in the way you know.\nRelease one leaf at break of day;\nAt noon release another leaf;\nOne from our trees, one far away.\nRetard the sun with gentle mist;\nEnchant the land with amethyst.\nSlow, slow!\nFor the grapes’ sake, if they were all,\nWhose leaves already are burnt with frost,\nWhose clustered fruit must else be lost—\nFor the grapes’ sake along the wall.',
#  'The buzz saw snarled and rattled in the yard\nAnd made dust and dropped stove-length sticks of wood,\nSweet-scented stuff when the breeze drew across it.\nAnd from there those that lifted eyes could count\nFive mountain ranges one behind the other\nUnder the sunset far into Vermont.\nAnd the saw snarled and rattled, snarled and rattled,\nAs it ran light, or had to bear a load.\nAnd nothing happened: day was all but done.\nCall it a day, I wish they might have said\nTo please the boy by giving him the half hour\nThat a boy counts so much when saved from work.\nHis sister stood beside him in her apron\nTo tell them ‘Supper.’ At the word, the saw,\nAs if to prove saws knew what supper meant,\nLeaped out at the boy’s hand, or seemed to leap—\nHe must have given the hand. However it was,\nNeither refused the meeting. But the hand!\nThe boy’s first outcry was a rueful laugh,\nAs he swung toward them holding up the hand\nHalf in appeal, but half as if to keep\nThe life from spilling. Then the boy saw all—\nSince he was old enough to know, big boy\nDoing a man’s work, though a child at heart—\nHe saw all spoiled. ‘Don’t let him cut my hand off—\nThe doctor, when he comes. Don’t let him, sister!’\nSo. But the hand was gone already.\nThe doctor put him in the dark of ether.\nHe lay and puffed his lips out with his breath.\nAnd then—the watcher at his pulse took fright.\nNo one believed. They listened at his heart.\nLittle—less—nothing!—and that ended it.\nNo more to build on there. And they, since they\nWere not the one dead, turned to their affairs.',
#  'Others taunt me with having knelt at well-curbs\nAlways wrong to the light, so never seeing\nDeeper down in the well than where the water\nGives me back in a shining surface picture\nMe myself in the summer heaven godlike\nLooking out of a wreath of fern and cloud puffs.\nOnce, when trying with chin against a well-curb,\nI discerned, as I thought, beyond the picture,\nThrough the picture, a something white, uncertain,\nSomething more of the depths—and then I lost it.\nWater came to rebuke the too clear water.\nOne drop fell from a fern, and lo, a ripple\nShook whatever it was lay there at bottom,\nBlurred it, blotted it out. What was that whiteness?\nTruth? A pebble of quartz? For once, then, something.',
#  'Why make so much of fragmentary blue\nIn here and there a bird, or butterfly,\nOr flower, or wearing-stone, or open eye,\nWhen heaven presents in sheets the solid hue?\nSince earth is earth, perhaps, not heaven (as yet)—\nThough some savants make earth include the sky;\nAnd blue so far above us comes so high,\nIt only gives our wish for blue a whet.',
#  'Spades take up leaves\nNo better than spoons,\nAnd bags full of leaves\nAre light as balloons.\nI make a great noise\nOf rustling all day\nLike rabbit and deer\nRunning away.\nBut the mountains I raise\nElude my embrace,\nFlowing over my arms\nAnd into my face.\nI may load and unload\nAgain and again\nTill I fill the whole shed,\nAnd what have I then?\nNext to nothing for weight,\nAnd since they grew duller\nFrom contact with earth,\nNext to nothing for color.\nNext to nothing for use,\nBut a crop is a crop,\nAnd who’s to say where\nThe harvest shall stop?',
#  'This saying good-by on the edge of the dark\nAnd the cold to an orchard so young in the bark\nReminds me of all that can happen to harm\nAn orchard away at the end of the farm\nAll winter, cut off by a hill from the house.\nI don\'t want it girdled by rabbit and mouse,\nI don\'t want it dreamily nibbled for browse\nBy deer, and I don\'t want it budded by grouse.\n(If certain it wouldn\'t be idle to call\nI\'d summon grouse, rabbit, and deer to the wall\nAnd warn them away with a stick for a gun.)\nI don\'t want it stirred by the heat of the sun.\n(We made it secure against being, I hope,\nBy setting it out on a northerly slope.)\nNo orchard\'s the worse for the wintriest storm;\nBut one thing about it, it mustn\'t get warm.\n"How often already you\'ve had to be told,\nKeep cold, young orchard. Good-by and keep cold.\nDread fifty above more than fifty below."\nI have to be gone for a season or so.\nMy business awhile is with different trees,\nLess carefully nourished, less fruitful than these,\nAnd such as is done to their wood with an ax—\nMaples and birches and tamaracks.\nI wish I could promise to lie in the night\nAnd think of an orchard\'s arboreal plight\nWhen slowly (and nobody comes with a light)\nIts heart sinks lower under the sod.\nBut something has to be left to God.',
#  "He saw her from the bottom of the stairs\nBefore she saw him. She was starting down,\nLooking back over her shoulder at some fear.\nShe took a doubtful step and then undid it\nTo raise herself and look again. He spoke\nAdvancing toward her: ‘What is it you see\nFrom up there always—for I want to know.’\nShe turned and sank upon her skirts at that,\nAnd her face changed from terrified to dull.\nHe said to gain time: ‘What is it you see,’\nMounting until she cowered under him.\n‘I will find out now—you must tell me, dear.’\nShe, in her place, refused him any help\nWith the least stiffening of her neck and silence.\nShe let him look, sure that he wouldn’t see,\nBlind creature; and awhile he didn’t see.\nBut at last he murmured, ‘Oh,’ and again, ‘Oh.’\n‘What is it—what?’ she said.\n‘Just that I see.’\n‘You don’t,’ she challenged. ‘Tell me what it is.’\n‘The wonder is I didn’t see at once.\nI never noticed it from here before.\nI must be wonted to it—that’s the reason.\nThe little graveyard where my people are!\n
#  'Nature’s first green is gold,\nHer hardest hue to hold.\nHer early leaf’s a flower;\nBut only so an hour.\nThen leaf subsides to leaf.\nSo Eden sank to grief,\nSo dawn goes down to day.\nNothing gold can stay.',
#  "The battle rent a cobweb diamond-strung\nAnd cut a flower beside a ground bird's nest\nBefore it stained a single human breast.\nThe stricken flower bent double and so hung.\nAnd still the bird revisited her young.\nA butterfly its fall had dispossessed\nA moment sought in air his flower of rest,\nThen lightly stooped to it and fluttering clung.\nOn the bare upland pasture there had spread\nO'ernight 'twixt mullein stalks a wheel of thread\nAnd straining cables wet with silver dew.\nA sudden passing bullet shook it dry.\nThe indwelling spider ran to greet the fly,\nBut finding nothing, sullenly withdrew.",
#  'Out through the fields and the woods\nAnd over the walls I have wended;\nI have climbed the hills of view\nAnd looked at the world, and descended;\nI have come by the highway home,\nAnd lo, it is ended.\nThe leaves are all dead on the ground,\nSave those that the oak is keeping\nTo ravel them one by one\nAnd let them go scraping and creeping\nOut over the crusted snow,\nWhen others are sleeping.\nAnd the dead leaves lie huddled and still,\nNo longer blown hither and thither;\nThe last lone aster is gone;\nThe flowers of the witch hazel wither;\nThe heart is still aching to seek,\nBut the feet question ‘Whither?’\nAh, when to the heart of man\nWas it ever less than a treason\nTo go with the drift of things,\nTo yield with a grace to reason,\nAnd bow and accept the end\nOf a love or a season?',
#  'Whose woods these are I think I know.\nHis house is in the village though;\nHe will not see me stopping here\nTo watch his woods fill up with snow.\nMy little horse must think it queer\nTo stop without a farmhouse near\nBetween the woods and frozen lake\nThe darkest evening of the year.\nHe gives his harness bells a shake\nTo ask if there is some mistake.\nThe only other sound’s the sweep\nOf easy wind and downy flake.\nThe woods are lovely, dark and deep,\nBut I have promises to keep,\nAnd miles to go before I sleep,\nAnd miles to go before I sleep.',
#  'Before man came to blow it right\nThe wind once blew itself untaught,\nAnd did its loudest day and night\nIn any rough place where it caught.\nMan came to tell it what was wrong:\nIt hadn’t found the place to blow;\nIt blew too hard—the aim was song.\nAnd listen—how it ought to go!\nHe took a little in his mouth,\nAnd held it long enough for north\nTo be converted into south,\nAnd then by measure blew it forth.\nBy measure. It was word and note,\nThe wind the wind had meant to be—\nA little through the lips and throat.\nThe aim was song—the wind could see.',
#  'I came an errand one cloud-blowing evening\nTo a slab-built, black-paper-covered house\nOf one room and one window and one door,\nThe only dwelling in a waste cut over\nA hundred square miles round it in the mountains:\nAnd that not dwelt in now by men or women.\n(It never had been dwelt in, though, by women,\nSo what is this I make a sorrow of?)\nI came as census-taker to the waste\nTo count the people in it and found none,\nNone in the hundred miles, none in the house,\nWhere I came last with some hope, but not much,\nAfter hours’ overlooking from the cliffs\nAn emptiness flayed to the very stone.\nI found no people that dared show themselves,\nNone

#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
# Add the clean lines in the poems dataframe
poems["lines"] = clean2

# Preview the dataframe
poems.head()
# Out:
#                        title  \
# 0                    October
# 1                ‘Out, Out—’
# 2  Acquainted with the Night
# 3        After Apple-Picking
# 4                    Birches
#
#                                                 link  \
# 0  https://www.poetryfoundation.org/poems/53084/o...
# 1  https://www.poetryfoundation.org/poems/53087/o...
# 2  https://www.poetryfoundation.org/poems/47548/a...
# 3  https://www.poetryfoundation.org/poems/44259/a...
# 4  https://www.poetryfoundation.org/poems/44260/b...
#
#                                                lines
# 0  O hushed October morning mild,\nThy leaves hav...
# 1  The buzz saw snarled and rattled in the yard\n...
# 2  I have been one acquainted with the night.\nI ...
# 3  My long two-pointed ladder's sticking through ...
# 4  When I see birches bend to left and right\nAcr...

# %%
# Remove rows with no text
poems["lines"].replace("", np.nan, inplace = True)

# Drop rows with NaNs in the lines column
poems.dropna(subset = ["lines"], inplace = True)

# Preview the size of the dataframe after dropping the rows with NaNs in the lines column
len(poems)
# Out:
# 37

# %% [markdown]
# ### Save the dataframe in a SQLIte database

# %%
# Dependencies
import sqlite3

# %%
# Create a SQLite database
conn = sqlite3.connect("db/Poetry.db")

# %%
# Create a database table from the dataframe
poems.to_sql("Frost", conn, if_exists = "replace")

# Preview the database table
pd.read_sql_query("select * from Frost;", conn)
# Out:
#     index                                       title  \
# 0       0                                     October
# 1       1                                 ‘Out, Out—’
# 2       2                   Acquainted with the Night
# 3       3                         After Apple-Picking
# 4       4                                     Birches
# 5       5                             Christmas Trees
# 6       6                                Dust of Snow
# 7       7                                Fire and Ice
# 8       8                     Fireflies in the Garden
# 9       9                   For Once, Then, Something
# 10     10                            Fragmentary Blue
# 11     11                            Gathering Leaves
# 12     12                       Good-by and Keep Cold
# 13     13                                 Home Burial
# 14     14                      In a Disused Graveyard
# 15     15                         Love and a Question
# 16     16                                Mending Wall
# 17     17                                      Mowing
# 18     18                                 Not to Keep
# 19     19                       Nothing Gold Can Stay
# 20     20                               Range-finding
# 21     21                                  Reluctance
# 22     22        Stopping by Woods on a Snowy Evening
# 23     23                            The Aim Was Song
# 24     24                            The Census-Taker
# 25     25                  The Death of the Hired Man
# 26     26                           The Gift Outright
# 27     27  The Need of Being Versed in Country Things
# 28     28                               The Oven Bird
# 29     29                                 The Pasture
# 30     30                          The Road Not Taken
# 31     31                                 The Runaway
# 32     32                          The Sound of Trees
# 33     33                           The Star-splitter
# 34     34                         The Tuft of Flowers
# 35     35                               The Wood-Pile
# 36     36                                    To E. T.
#
#                                                  link  \
# 0   https://www.poetryfoundation.org/poems/53084/o...
# 1   https://www.poetryfoundation.org/poems/53087/o...
# 2   https://www.poetryfoundation.org/poems/47548/a...
# 3   https://www.poetryfoundation.org/poems/44259/a...
# 4   https://www.poetryfoundation.org/poems/44260/b...
# 5   https://www.poetryfoundation.org/poems/57834/c...
# 6   https://www.poetryfoundation.org/poems/44262/d...
# 7   https://www.poetryfoundation.org/poems/44263/f...
# 8   https://www.poetryfoundation.org/poems/42892/f...
# 9   https://www.poetryfoundation.org/poems/44264/f...
# 10  https://www.poetryfoundation.org/poems/148650/...
# 11  https://www.poetryfoundation.org/poems/148658/...
# 12  https://www.poetryfoundation.org/poems/44265/g...
# 13  https://www.poetryfoundation.org/poems/53086/h...
# 14  https://www.poetryfoundation.org/poems/148651/...
# 15  https://www.poetryfoundation.org/poems/53000/l...
# 16  https://www.poetryfoundation.org/poems/44266/m...
# 17  https://www.poetryfoundation.org/poems/53001/m...
# 18  https://www.poetryfoundation.org/poems/148657/...
# 19  https://www.poetryfoundation.org/poems/148652/...
# 20  https://www.poetryfoundation.org/poems/44271/r...
# 21  https://www.poetryfoundation.org/poems/53085/r...
# 22  https://www.poetryfoundation.org/poems/42891/s...
# 23  https://www.poetryfoundation.org/poems/148655/...
# 24  https://www.poetryfoundation.org/poems/148649/...
# 25  https://www.poetryfoundation.org/poems/44261/t...
# 26  https://www.poetryfoundation.org/poems/53013/t...
# 27  https://www.poetryfoundation.org/poems/148659/...
# 28  https://www.poetryfoundation.org/poems/44269/t...
# 29  https://www.poetryfoundation.org/poems/44270/t...
# 30  https://www.poetryfoundation.org/poems/44272/t...
# 31  https://www.poetryfoundation.org/poems/148653/...
# 32  https://www.poetryfoundation.org/poems/53088/t...
# 33  https://www.poetryfoundation.org/poems/44273/t...
# 34  https://www.poetryfoundation.org/poems/44275/t...
# 35  https://www.poetryfoundation.org/poems/44276/t...
# 36  https://www.poetryfoundation.org/poems/44274/t...
#
#                                                 lines
# 0   O hushed October morning mild,\nThy leaves hav...
# 1   The buzz saw snarled and rattled in the yard\n...
# 2   I have been one acquainted with the night.\nI ...
# 3   My long two-pointed ladder's sticking through ...
# 4   When I see birches bend to left and right\nAcr...
# 5   The city had withdrawn into itself\nAnd left a...
# 6   The way a crow\nShook down on me\nThe dust of ...
# 7   Some say the world will end in fire,\nSome say...
# 8   Here come real stars to fill the upper skies,\...
# 9   Others taunt me with having knelt at well-curb...
# 10  Why make so much of fragmentary blue\nIn here ...
# 11  Spades take up leaves\nNo better than spoons,\...
# 12  This saying good-by on the edge of the dark\nA...
# 13  He saw her from the bottom of the stairs\nBefo...
# 14  The living come with grassy tread\nTo read the...
# 15  A Stranger came to the door at eve,\nAnd he sp...
# 16  Something there is that doesn't love a wall,\n...
# 17  There was never a sound beside the wood but on...
# 18  They sent him back to her. The letter came\nSa...
# 19  Nature’s first green is gold,\nHer hardest hue...
# 20  The battle rent a cobweb diamond-strung\nAnd c...
# 21  Out through the fields and the woods\nAnd over...
# 22  Whose woods these are I think I know.\nHis hou...
# 23  Before man came to blow it right\nThe wind onc...
# 24  I came an errand one cloud-blowing evening\nTo...
# 25  Mary sat musing on the lamp-flame at the table...
# 26  The land was ours before we were the land’s.\n...
# 27  The house had gone to bring again\nTo the midn...
# 28  There is a singer everyone has heard,\nLoud, a...
# 29  I'm going out to clean the pasture spring;\nI'...
# 30  Two roads diverged in a yellow wood,\nAnd sorr...
# 31  Once when the snow of the year was beginning t...
# 32  I wonder about the trees.\nWhy do we wish to b...
# 33  "You know Orion always comes up sideways.\nThr...
# 34  I went to turn the grass once after one\nWho m...
# 35  Out walking in the frozen swamp one gray day,\...
# 36  I slumbered with your poems on my breast\nSpre...
